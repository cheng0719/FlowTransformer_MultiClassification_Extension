# %%
import os

import pandas as pd

from framework.dataset_specification import NamedDatasetSpecifications
from framework.enumerations import EvaluationDatasetSampling
from framework.flow_transformer_binary_classification import FlowTransformer
from framework.flow_transformer_parameters import FlowTransformerParameters
from implementations.classification_heads import *
from implementations.input_encodings import * 
from implementations.pre_processings import StandardPreProcessing
from implementations.transformers.basic_transformers import BasicTransformer
from implementations.transformers.named_transformers import *
# Out:
# 2024-10-13 13:31:53.571491: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-13 13:31:53.580494: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-13 13:31:53.589943: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-13 13:31:53.592750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-13 13:31:53.600490: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-13 13:31:54.014911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
encodings = [
    NoInputEncoder(),
    RecordLevelEmbed(64),
    CategoricalFeatureEmbed(EmbedLayerType.Dense, 16),
    CategoricalFeatureEmbed(EmbedLayerType.Lookup, 16),
    CategoricalFeatureEmbed(EmbedLayerType.Projection, 16),
    RecordLevelEmbed(64, project=True)
]

classification_heads = [
    LastTokenClassificationHead(),
    FlattenClassificationHead(),
    GlobalAveragePoolingClassificationHead(),
    CLSTokenClassificationHead(),
    FeaturewiseEmbedding(project=False),
    FeaturewiseEmbedding(project=True),
]

transformers = [
    BasicTransformer(2, 128, n_heads=2),
    BasicTransformer(2, 128, n_heads=2, is_decoder=True),
    GPTSmallTransformer(),
    BERTSmallTransformer()
]

# %%
flow_file_path = "./dataset"

datasets = [
    ("CSE_CIC_IDS", os.path.join(flow_file_path, "NF-CSE-CIC-IDS2018-v2.csv"), NamedDatasetSpecifications.unified_flow_format, 0.01, EvaluationDatasetSampling.LastRows),
    ("UNSW_NB15", os.path.join(flow_file_path, "NF-UNSW-NB15-v2.csv"), NamedDatasetSpecifications.unified_flow_format, 0.025, EvaluationDatasetSampling.LastRows),
    ("UNSW_NB15-2", os.path.join(flow_file_path, "NF-UNSW-NB15-v2.csv"), NamedDatasetSpecifications.unified_flow_format, 0.1, EvaluationDatasetSampling.LastRows),
]

# %%
pre_processing = StandardPreProcessing(n_categorical_levels=32)

# Define the transformer
ft = FlowTransformer(pre_processing=pre_processing,
                     input_encoding=encodings[5],
                     sequential_model=transformers[1],
                     classification_head=classification_heads[5],
                     params=FlowTransformerParameters(window_size=10, mlp_layer_sizes=[128], mlp_dropout=0.1))

# Load the specific dataset
cache_folder = './content/cache_folder'
dataset_name, dataset_path, dataset_specification, eval_percent, eval_method = datasets[1]
ft.load_dataset(dataset_name, dataset_path, dataset_specification, cache_folder, evaluation_percent=eval_percent)
# Out:
# Using cache file path: ./content/cache_folder/UNSW_NB15_0_QdLmZHuh8yOmlGcKBEkf7hepImY0_VzQ981ONg0PHPxtLtik6rZN0dGw0.feather
# Reading directly from cache ./content/cache_folder/UNSW_NB15_0_QdLmZHuh8yOmlGcKBEkf7hepImY0_VzQ981ONg0PHPxtLtik6rZN0dGw0.feather...
#          DURATION_OUT  OUT_BYTES  NUM_PKTS_512_TO_1024_BYTES  MIN_IP_PKT_LEN  \
# 0                 0.0   0.319254                    0.000000        0.608608
# 1                 0.0   0.372881                    0.000000        0.608608
# 2                 0.0   0.401284                    0.000000        0.608608
# 3                 0.0   0.421883                    0.000000        0.608608
# 4                 0.0   0.442193                    0.000000        0.608608
# ...               ...        ...                         ...             ...
# 2390270           0.0   0.470805                    0.164319        0.608608
# 2390271           0.0   0.314377                    0.000000        0.659772
# 2390272           0.0   0.551102                    0.000000        0.608608
# 2390273           0.0   0.667044                    0.000000        0.608608
# 2390274           0.0   0.576359                    0.164319        0.608608
#
#          NUM_PKTS_1024_TO_1514_BYTES  MAX_IP_PKT_LEN  RETRANSMITTED_IN_PKTS  \
# 0                           0.000000        0.565324               0.000000
# 1                           0.000000        0.565324               0.074172
# 2                           0.000000        0.575948               0.117560
# 3                           0.000000        0.598516               0.148344
# 4                           0.000000        0.598516               0.172222
# ...                              ...             ...                    ...
# 2390270                     0.000000        0.915812               0.148344
# 2390271                     0.000000        0.565324               0.000000
# 2390272                     0.196811        0.999258               0.074172
# 2390273                     0.385009        0.984754               0.208227
# 2390274                     0.222229        0.984754               0.208227
#
#          TCP_WIN_MAX_IN  NUM_PKTS_UP_TO_128_BYTES  RETRANSMITTED_IN_BYTES  \
# 0              0.000000                  0.326896                0.000000
# 1              0.817813                  0.374701                0.261166
# 2              0.831711                  0.408620                0.295819
# 3              0.843750                  0.434929                0.317712
# 4              0.863869                  0.465863                0.334477
# ...                 ...                       ...                     ...
# 2390270        0.831711                  0.369683                0.358198
# 2390271        0.000000                  0.189757                0.000000
# 2390272        0.831711                  0.302415                0.342133
# 2390273        0.965882                  0.536915                0.381469
# 2390274        0.894207                  0.472476                0.381469
#
#          ...  L7_PROTO_23  L7_PROTO_24  L7_PROTO_25  L7_PROTO_26  L7_PROTO_27  \
# 0        ...        False        False        False        False        False
# 1        ...        False        False        False        False        False
# 2        ...        False        False        False        False        False
# 3        ...        False        False        False        False        False
# 4        ...        False        False        False        False        False
# ...      ...          ...          ...          ...          ...          ...
# 2390270  ...        False        False        False        False        False
# 2390271  ...        False        False        False        False        False
# 2390272  ...        False        False        False        False        False
# 2390273  ...        False        False        False        False        False
# 2390274  ...        False        False        False        False        False
#
#          L7_PROTO_28  L7_PROTO_29  L7_PROTO_30  L7_PROTO_31  L7_PROTO_32
# 0              False        False        False        False        False
# 1              False        False        False        False        False
# 2              False        False        False        False        False
# 3              False        False        False        False        False
# 4              False        False        False        False        False
# ...              ...          ...          ...          ...          ...
# 2390270        False        False        False        False        False
# 2390271        False        False        False        False        False
# 2390272        False        False        False        False        False
# 2390273        False        False        False        False        False
# 2390274        False        False        False        False        False
#
# [2390275 rows x 268 columns]

# %%
m = ft.build_model()
m.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728797549.316170 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.341581 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.341697 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.343262 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.343346 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.343400 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.492539 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.492651 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728797549.492715 1396941 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-13 13:32:29.492766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2381 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_DURATION_OUT  │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_OUT_BYTES     │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_NUM_PKTS_512… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_MIN_IP_PKT_L… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_NUM_PKTS_102… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_MAX_IP_PKT_L… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_RETRANSMITTE… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_TCP_WIN_MAX_… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_NUM_PKTS_UP_… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_RETRANSMITTE… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_DURATION_IN   │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_RETRANSMITTE… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_OUT_PKTS      │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_FLOW_DURATIO… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_LONGEST_FLOW… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_DST_TO_SRC_S… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_SRC_TO_DST_A… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_IN_PKTS       │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_NUM_PKTS_256… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_IN_BYTES      │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_TCP_WIN_MAX_… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_MIN_TTL       │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_MAX_TTL       │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_SRC_TO_DST_S… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_DST_TO_SRC_A… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_NUM_PKTS_128… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_SHORTEST_FLO… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_RETRANSMITTE… │ (None, 10, 1)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_CLIENT_TCP_F… │ (None, 10, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_L4_SRC_PORT   │ (None, 10, 32)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_TCP_FLAGS     │ (None, 10, 17)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_ICMP_IPV4_TY… │ (None, 10, 32)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_ICMP_TYPE     │ (None, 10, 32)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_PROTOCOL      │ (None, 10, 32)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_SERVER_TCP_F… │ (None, 10, 15)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_L4_DST_PORT   │ (None, 10, 32)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_L7_PROTO      │ (None, 10, 32)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_concat      │ (None, 10, 268)   │          0 │ input_DURATION_O… │
# │ (Concatenate)       │                   │            │ input_OUT_BYTES[… │
# │                     │                   │            │ input_NUM_PKTS_5… │
# │                     │                   │            │ input_MIN_IP_PKT… │
# │                     │                   │            │ input_NUM_PKTS_1… │
# │                     │                   │            │ input_MAX_IP_PKT… │
# │                     │                   │            │ input_RETRANSMIT… │
# │                     │                   │            │ input_TCP_WIN_MA… │
# │                     │                   │            │ input_NUM_PKTS_U… │
# │                     │                   │            │ input_RETRANSMIT… │
# │                     │                   │            │ input_DURATION_I… │
# │                     │                   │            │ input_RETRANSMIT… │
# │                     │                   │            │ input_OUT_PKTS[0… │
# │                     │                   │            │ input_FLOW_DURAT… │
# │                     │                   │            │ input_LONGEST_FL… │
# │                     │                   │            │ input_DST_TO_SRC… │
# │                     │                   │            │ input_SRC_TO_DST… │
# │                     │                   │            │ input_IN_PKTS[0]… │
# │                     │                   │            │ input_NUM_PKTS_2… │
# │                     │                   │            │ input_IN_BYTES[0… │
# │                     │                   │            │ input_TCP_WIN_MA… │
# │                     │                   │            │ input_MIN_TTL[0]… │
# │                     │                   │            │ input_MAX_TTL[0]… │
# │                     │                   │            │ input_SRC_TO_DST… │
# │                     │                   │            │ input_DST_TO_SRC… │
# │                     │                   │            │ input_NUM_PKTS_1… │
# │                     │                   │            │ input_SHORTEST_F… │
# │                     │                   │            │ input_RETRANSMIT… │
# │                     │                   │            │ input_CLIENT_TCP… │
# │                     │                   │            │ input_L4_SRC_POR… │
# │                     │                   │            │ input_TCP_FLAGS[… │
# │                     │                   │            │ input_ICMP_IPV4_… │
# │                     │                   │            │ input_ICMP_TYPE[… │
# │                     │                   │            │ input_PROTOCOL[0… │
# │                     │                   │            │ input_SERVER_TCP… │
# │                     │                   │            │ input_L4_DST_POR… │
# │                     │                   │            │ input_L7_PROTO[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embed (Dense)       │ (None, 10, 64)    │     17,152 │ feature_concat[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_decode… │ (None, 10, 64)    │     50,048 │ embed[0][0]       │
# │ (TransformerDecode… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_decode… │ (None, 10, 64)    │     50,048 │ transformer_deco… │
# │ (TransformerDecode… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ featurewise_embed   │ (None, 10, 1)     │         64 │ transformer_deco… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 10)        │          0 │ featurewise_embe… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification_mlp… │ (None, 128)       │      1,408 │ flatten[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ classification_m… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ binary_classificat… │ (None, 1)         │        129 │ dropout_6[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 118,849 (464.25 KB)
#  Trainable params: 118,849 (464.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
m.compile(optimizer="adam", loss='binary_crossentropy', metrics=['binary_accuracy'], jit_compile=True)

# Get the evaluation results
eval_results: pd.DataFrame
(train_results, eval_results, final_epoch) = ft.evaluate(m, batch_size=128, epochs=5, steps_per_epoch=64, early_stopping_patience=5)

print(eval_results)
# Out:
# Attack classes in eval set:
# 	Exploits
# 	Generic
# 	Fuzzers
# 	Backdoor
# 	DoS
# 	Reconnaissance
# 	Shellcode
# 	Worms
# 	Analysis
# Building eval dataset...
# Splitting dataset to featurewise...
# Evaluation dataset is built!
#
# Positive samples in eval set: 2816
# Negative samples in eval set: 56931
#
# Computing and print the number of each attack class in the evaluation set...
# Attack class Exploits samples in eval set: 1285
# Attack class Generic samples in eval set: 143
# Attack class Fuzzers samples in eval set: 639
# Attack class Backdoor samples in eval set: 19
# Attack class DoS samples in eval set: 182
# Attack class Reconnaissance samples in eval set: 481
# Attack class Shellcode samples in eval set: 57
# Attack class Worms samples in eval set: 7
# Attack class Analysis samples in eval set: 3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728797630.017233 1397055 service.cc:146] XLA service 0x7d7440003080 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728797630.017257 1397055 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4080, Compute Capability 8.9
# 2024-10-13 13:33:50.090783: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-13 13:33:50.708808: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-10-13 13:33:51.190353: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_153', 12 bytes spill stores, 12 bytes spill loads
#
# 2024-10-13 13:33:52.080926: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_155', 12 bytes spill stores, 12 bytes spill loads
#
# 2024-10-13 13:33:52.979336: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_103', 16 bytes spill stores, 16 bytes spill loads
#
# 2024-10-13 13:33:53.436153: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_106', 72 bytes spill stores, 72 bytes spill loads
#
# I0000 00:00:1728797638.839866 1397055 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch = 0 / 5 (early stop in 5), step = 0, loss = 0.69497, results = [array(0.694968, dtype=float32), array(0.515625, dtype=float32)] -- elapsed (train): 0.00s
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7d76593d8b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7d76593d8b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch = 0 / 5 (early stop in 5), step = 5, loss = 0.67744, results = [array(0.67744476, dtype=float32), array(0.57161456, dtype=float32)] -- elapsed (train): 2.11s
# Epoch = 0 / 5 (early stop in 5), step = 10, loss = 0.63927, results = [array(0.63926977, dtype=float32), array(0.6328125, dtype=float32)] -- elapsed (train): 3.87s
# Epoch = 0 / 5 (early stop in 5), step = 15, loss = 0.58121, results = [array(0.581212, dtype=float32), array(0.69189453, dtype=float32)] -- elapsed (train): 5.63s
# Epoch = 0 / 5 (early stop in 5), step = 20, loss = 0.50781, results = [array(0.50780743, dtype=float32), array(0.74404764, dtype=float32)] -- elapsed (train): 7.39s
# Epoch = 0 / 5 (early stop in 5), step = 25, loss = 0.44611, results = [array(0.44611388, dtype=float32), array(0.77944714, dtype=float32)] -- elapsed (train): 9.16s
# Epoch = 0 / 5 (early stop in 5), step = 30, loss = 0.39818, results = [array(0.39817595, dtype=float32), array(0.8079637, dtype=float32)] -- elapsed (train): 10.93s
# Epoch = 0 / 5 (early stop in 5), step = 35, loss = 0.36042, results = [array(0.36042482, dtype=float32), array(0.82942706, dtype=float32)] -- elapsed (train): 12.70s
# Epoch = 0 / 5 (early stop in 5), step = 40, loss = 0.32860, results = [array(0.32859668, dtype=float32), array(0.84698933, dtype=float32)] -- elapsed (train): 14.48s
# Epoch = 0 / 5 (early stop in 5), step = 45, loss = 0.30408, results = [array(0.30408406, dtype=float32), array(0.8602242, dtype=float32)] -- elapsed (train): 16.26s
# Epoch = 0 / 5 (early stop in 5), step = 50, loss = 0.28395, results = [array(0.2839493, dtype=float32), array(0.8714767, dtype=float32)] -- elapsed (train): 18.04s
# Epoch = 0 / 5 (early stop in 5), step = 55, loss = 0.26598, results = [array(0.26598176, dtype=float32), array(0.8808594, dtype=float32)] -- elapsed (train): 19.83s
# Epoch = 0 / 5 (early stop in 5), step = 60, loss = 0.25113, results = [array(0.25113454, dtype=float32), array(0.8885758, dtype=float32)] -- elapsed (train): 21.63s
# Epoch = 1 / 5 (early stop in 5), step = 1, loss = 0.23655, results = [array(0.23654607, dtype=float32), array(0.89571494, dtype=float32)] -- elapsed (train): 23.43s
# Epoch = 1 / 5 (early stop in 5), step = 6, loss = 0.22415, results = [array(0.2241452, dtype=float32), array(0.90195864, dtype=float32)] -- elapsed (train): 25.23s
# Epoch = 1 / 5 (early stop in 5), step = 10, loss = 0.21391, results = [array(0.21390541, dtype=float32), array(0.9066667, dtype=float32)] -- elapsed (train): 26.68s
# Epoch = 1 / 5 (early stop in 5), step = 14, loss = 0.20657, results = [array(0.2065739, dtype=float32), array(0.9104035, dtype=float32)] -- elapsed (train): 28.13s
# Epoch = 1 / 5 (early stop in 5), step = 19, loss = 0.19754, results = [array(0.19754107, dtype=float32), array(0.91480654, dtype=float32)] -- elapsed (train): 29.95s
# Epoch = 1 / 5 (early stop in 5), step = 23, loss = 0.19007, results = [array(0.19007283, dtype=float32), array(0.9180575, dtype=float32)] -- elapsed (train): 31.41s
# Epoch = 1 / 5 (early stop in 5), step = 27, loss = 0.18379, results = [array(0.18378682, dtype=float32), array(0.92128056, dtype=float32)] -- elapsed (train): 32.87s
# Epoch = 1 / 5 (early stop in 5), step = 32, loss = 0.17750, results = [array(0.1774952, dtype=float32), array(0.9246134, dtype=float32)] -- elapsed (train): 34.69s
# Epoch = 1 / 5 (early stop in 5), step = 36, loss = 0.17458, results = [array(0.17457755, dtype=float32), array(0.9265161, dtype=float32)] -- elapsed (train): 36.16s
# Epoch = 1 / 5 (early stop in 5), step = 40, loss = 0.17008, results = [array(0.17008157, dtype=float32), array(0.9285714, dtype=float32)] -- elapsed (train): 37.63s
# Epoch = 1 / 5 (early stop in 5), step = 44, loss = 0.16602, results = [array(0.16602045, dtype=float32), array(0.9307626, dtype=float32)] -- elapsed (train): 39.09s
# Epoch = 1 / 5 (early stop in 5), step = 48, loss = 0.16188, results = [array(0.1618813, dtype=float32), array(0.9326604, dtype=float32)] -- elapsed (train): 40.56s
# Epoch = 1 / 5 (early stop in 5), step = 52, loss = 0.15879, results = [array(0.15879393, dtype=float32), array(0.9344284, dtype=float32)] -- elapsed (train): 42.03s
# Epoch = 1 / 5 (early stop in 5), step = 56, loss = 0.15516, results = [array(0.15516372, dtype=float32), array(0.9363378, dtype=float32)] -- elapsed (train): 43.51s
# Epoch = 1 / 5 (early stop in 5), step = 60, loss = 0.15209, results = [array(0.15208924, dtype=float32), array(0.9378125, dtype=float32)] -- elapsed (train): 44.99s
# Epoch = 2 / 5 (early stop in 5), step = 0, loss = 0.14795, results = [array(0.14794911, dtype=float32), array(0.93949854, dtype=float32)] -- elapsed (train): 46.47s
# Epoch = 2 / 5 (early stop in 5), step = 4, loss = 0.14463, results = [array(0.14462847, dtype=float32), array(0.9411419, dtype=float32)] -- elapsed (train): 47.95s
# Epoch = 2 / 5 (early stop in 5), step = 8, loss = 0.14162, results = [array(0.14161868, dtype=float32), array(0.9426893, dtype=float32)] -- elapsed (train): 49.43s
# Epoch = 2 / 5 (early stop in 5), step = 12, loss = 0.13941, results = [array(0.1394112, dtype=float32), array(0.9439827, dtype=float32)] -- elapsed (train): 50.92s
# Epoch = 2 / 5 (early stop in 5), step = 16, loss = 0.13662, results = [array(0.1366183, dtype=float32), array(0.9452586, dtype=float32)] -- elapsed (train): 52.40s
# Epoch = 2 / 5 (early stop in 5), step = 20, loss = 0.13423, results = [array(0.13423017, dtype=float32), array(0.9465185, dtype=float32)] -- elapsed (train): 53.89s
# Epoch = 2 / 5 (early stop in 5), step = 24, loss = 0.13145, results = [array(0.1314473, dtype=float32), array(0.94766134, dtype=float32)] -- elapsed (train): 55.38s
# Epoch = 2 / 5 (early stop in 5), step = 28, loss = 0.12911, results = [array(0.12911257, dtype=float32), array(0.948746, dtype=float32)] -- elapsed (train): 56.86s
# Epoch = 2 / 5 (early stop in 5), step = 32, loss = 0.12670, results = [array(0.12670344, dtype=float32), array(0.94972825, dtype=float32)] -- elapsed (train): 58.36s
# Epoch = 2 / 5 (early stop in 5), step = 36, loss = 0.12531, results = [array(0.12530656, dtype=float32), array(0.9506155, dtype=float32)] -- elapsed (train): 59.86s
# Epoch = 2 / 5 (early stop in 5), step = 40, loss = 0.12319, results = [array(0.12319306, dtype=float32), array(0.95150703, dtype=float32)] -- elapsed (train): 61.36s
# Epoch = 2 / 5 (early stop in 5), step = 44, loss = 0.12111, results = [array(0.12111291, dtype=float32), array(0.9523573, dtype=float32)] -- elapsed (train): 62.86s
# Epoch = 2 / 5 (early stop in 5), step = 48, loss = 0.11930, results = [array(0.11930361, dtype=float32), array(0.9532133, dtype=float32)] -- elapsed (train): 64.36s
# Epoch = 2 / 5 (early stop in 5), step = 52, loss = 0.11759, results = [array(0.11758652, dtype=float32), array(0.95407456, dtype=float32)] -- elapsed (train): 65.87s
# Epoch = 2 / 5 (early stop in 5), step = 56, loss = 0.11534, results = [array(0.11533622, dtype=float32), array(0.9550253, dtype=float32)] -- elapsed (train): 67.37s
# Epoch = 2 / 5 (early stop in 5), step = 60, loss = 0.11352, results = [array(0.11351628, dtype=float32), array(0.95581186, dtype=float32)] -- elapsed (train): 68.89s
# Epoch = 3 / 5 (early stop in 5), step = 0, loss = 0.11188, results = [array(0.11188163, dtype=float32), array(0.95652527, dtype=float32)] -- elapsed (train): 70.40s
# Epoch = 3 / 5 (early stop in 5), step = 4, loss = 0.11068, results = [array(0.1106806, dtype=float32), array(0.95709074, dtype=float32)] -- elapsed (train): 71.91s
# Epoch = 3 / 5 (early stop in 5), step = 8, loss = 0.10924, results = [array(0.10924441, dtype=float32), array(0.9577503, dtype=float32)] -- elapsed (train): 73.42s
# Epoch = 3 / 5 (early stop in 5), step = 12, loss = 0.10765, results = [array(0.10764971, dtype=float32), array(0.95842224, dtype=float32)] -- elapsed (train): 74.94s
# Epoch = 3 / 5 (early stop in 5), step = 16, loss = 0.10785, results = [array(0.10785364, dtype=float32), array(0.9586947, dtype=float32)] -- elapsed (train): 76.45s
# Epoch = 3 / 5 (early stop in 5), step = 20, loss = 0.10658, results = [array(0.10657707, dtype=float32), array(0.95917696, dtype=float32)] -- elapsed (train): 77.97s
# Epoch = 3 / 5 (early stop in 5), step = 24, loss = 0.10497, results = [array(0.10497058, dtype=float32), array(0.9598574, dtype=float32)] -- elapsed (train): 79.50s
# Epoch = 3 / 5 (early stop in 5), step = 28, loss = 0.10322, results = [array(0.1032183, dtype=float32), array(0.96054864, dtype=float32)] -- elapsed (train): 81.03s
# Epoch = 3 / 5 (early stop in 5), step = 32, loss = 0.10148, results = [array(0.10147923, dtype=float32), array(0.96125, dtype=float32)] -- elapsed (train): 82.56s
# Epoch = 3 / 5 (early stop in 5), step = 36, loss = 0.10037, results = [array(0.10037342, dtype=float32), array(0.96172214, dtype=float32)] -- elapsed (train): 84.09s
# Epoch = 3 / 5 (early stop in 5), step = 40, loss = 0.10007, results = [array(0.10006507, dtype=float32), array(0.962044, dtype=float32)] -- elapsed (train): 85.61s
# Epoch = 3 / 5 (early stop in 5), step = 44, loss = 0.09979, results = [array(0.09979133, dtype=float32), array(0.9622231, dtype=float32)] -- elapsed (train): 87.14s
# Epoch = 3 / 5 (early stop in 5), step = 48, loss = 0.09856, results = [array(0.09855527, dtype=float32), array(0.96272045, dtype=float32)] -- elapsed (train): 88.68s
# Epoch = 3 / 5 (early stop in 5), step = 52, loss = 0.09762, results = [array(0.09762145, dtype=float32), array(0.96313775, dtype=float32)] -- elapsed (train): 90.21s
# Epoch = 3 / 5 (early stop in 5), step = 56, loss = 0.09729, results = [array(0.09728552, dtype=float32), array(0.9634789, dtype=float32)] -- elapsed (train): 91.75s
# Epoch = 3 / 5 (early stop in 5), step = 60, loss = 0.09649, results = [array(0.09649072, dtype=float32), array(0.96390194, dtype=float32)] -- elapsed (train): 93.30s
# Epoch = 4 / 5 (early stop in 5), step = 0, loss = 0.09564, results = [array(0.09564496, dtype=float32), array(0.9643422, dtype=float32)] -- elapsed (train): 94.85s
# Epoch = 4 / 5 (early stop in 5), step = 4, loss = 0.09444, results = [array(0.09444372, dtype=float32), array(0.96473897, dtype=float32)] -- elapsed (train): 96.41s
# Epoch = 4 / 5 (early stop in 5), step = 8, loss = 0.09369, results = [array(0.09368596, dtype=float32), array(0.96512383, dtype=float32)] -- elapsed (train): 97.96s
# Epoch = 4 / 5 (early stop in 5), step = 12, loss = 0.09248, results = [array(0.09248172, dtype=float32), array(0.96561337, dtype=float32)] -- elapsed (train): 99.51s
# Epoch = 4 / 5 (early stop in 5), step = 16, loss = 0.09176, results = [array(0.09175844, dtype=float32), array(0.96600276, dtype=float32)] -- elapsed (train): 101.07s
# Epoch = 4 / 5 (early stop in 5), step = 20, loss = 0.09080, results = [array(0.09080427, dtype=float32), array(0.9664655, dtype=float32)] -- elapsed (train): 102.64s
# Epoch = 4 / 5 (early stop in 5), step = 24, loss = 0.09010, results = [array(0.09010025, dtype=float32), array(0.966776, dtype=float32)] -- elapsed (train): 104.20s
# Epoch = 4 / 5 (early stop in 5), step = 28, loss = 0.08935, results = [array(0.08934873, dtype=float32), array(0.9671327, dtype=float32)] -- elapsed (train): 105.76s
# Epoch = 4 / 5 (early stop in 5), step = 32, loss = 0.08877, results = [array(0.0887698, dtype=float32), array(0.9674254, dtype=float32)] -- elapsed (train): 107.34s
# Epoch = 4 / 5 (early stop in 5), step = 36, loss = 0.08830, results = [array(0.08830343, dtype=float32), array(0.96771014, dtype=float32)] -- elapsed (train): 108.91s
# Epoch = 4 / 5 (early stop in 5), step = 40, loss = 0.08730, results = [array(0.08730415, dtype=float32), array(0.968145, dtype=float32)] -- elapsed (train): 110.48s
# Epoch = 4 / 5 (early stop in 5), step = 44, loss = 0.08672, results = [array(0.0867219, dtype=float32), array(0.9684645, dtype=float32)] -- elapsed (train): 112.06s
# Epoch = 4 / 5 (early stop in 5), step = 48, loss = 0.08632, results = [array(0.08632051, dtype=float32), array(0.9686988, dtype=float32)] -- elapsed (train): 113.65s
# Epoch = 4 / 5 (early stop in 5), step = 52, loss = 0.08552, results = [array(0.08552013, dtype=float32), array(0.9690281, dtype=float32)] -- elapsed (train): 115.23s
# Epoch = 4 / 5 (early stop in 5), step = 56, loss = 0.08477, results = [array(0.08477433, dtype=float32), array(0.96932405, dtype=float32)] -- elapsed (train): 116.82s
# Epoch = 4 / 5 (early stop in 5), step = 60, loss = 0.08440, results = [array(0.08440481, dtype=float32), array(0.9695633, dtype=float32)] -- elapsed (train): 118.40s
# 1868/1868 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step
# Epoch 4 yielded predictions: (59747,), overall balanced accuracy: 99.12%, TP = 2,798 / 2,816, TN = 56,295 / 56,931
# Exploits: CORRECT = 1277, WRONG = 8
# Generic: CORRECT = 141, WRONG = 2
# Fuzzers: CORRECT = 637, WRONG = 2
# Backdoor: CORRECT = 17, WRONG = 2
# DoS: CORRECT = 179, WRONG = 3
# Reconnaissance: CORRECT = 480, WRONG = 1
# Shellcode: CORRECT = 57, WRONG = 0
# Worms: CORRECT = 7, WRONG = 0
# Analysis: CORRECT = 3, WRONG = 0
#    epoch     P      N  pred_P  pred_N    TP   FP     TN  FN   bal_acc       f1
# 0      4  2816  56931    3434   56313  2798  636  56295  18  0.991218  0.89536
